# %%
from programacion_no_lineal import *

# %% [markdown]
# Este trabajo tiene como finalidad implementar 4 de los métodos iterativos de optimización no lineales sin restricciones vistos en el curso de Matemáticas Avanzadas. La función con la que se trabajará es la siguiente:
#
#
# <div style="text-align:center">
#
# $\displaystyle \frac{x_{1}^{6}}{6} - 1.05 x_{1}^{4} + 2 x_{1}^{2} + x_{1} x_{2} + x_{2}^{2}$
#
# </div>
#
# Además, se implementaron funciones exclusivas para hacer uso de la búsqueda lineal en cada uno de los métodos y gradiente y matriz hessiana en los casos donde sean aplicables.

# %% [markdown]
# La función **Three-Hump Camel** tiene mínimo global en (0,0) y mínimo local en (1.7475, -0.8737) y (-1.7475, 0.8737)

# %% [markdown]
# ![puntos](puntos.png)

# %% [markdown]
# El gradiente y matriz hessiana de la función objetivo son los siguientes:

# %% [markdown]
# <div style="text-align:center">
#
# $\displaystyle \left[ x_{1}^{5} - 4.2 x_{1}^{3} + 4 x_{1} + x_{2}, \  x_{1} + 2 x_{2}\right]$
#
# </div>

# %% [markdown]
# <div style="text-align:center">
#
# $\displaystyle \left[\begin{matrix}5 x_{1}^{4} - 12.6 x_{1}^{2} + 4 & 1\\1 & 2\end{matrix}\right]$
#
# </div>

# %% [markdown]
# El gráfico de la izquierda muestra la función en su dominio de entrada recomendado, y el gráfico de la derecha muestra una parte de este dominio, para permitir una visualización más sencilla de las características clave de la función.

# %%
grafica()

# %%
menu()
# Out:
# Selecciona un método
# 1. Gradiente Descendente
# 2. Newton
# 3. Cuasi Newton (BFGS)
# 4. Powell
# Iteración 1: Punto actual: [-1.76804976  0.73040711]
# Iteración 2: Punto actual: [-1.74765385  0.87390543]
# Iteración 3: Punto actual: [-1.74755235  0.87377617]
# Punto óptimo:  [-1.74755235  0.87377617]
